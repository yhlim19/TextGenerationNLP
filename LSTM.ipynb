# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
import string
import requests

# %%
response = requests.get('https://www.gutenberg.org/cache/epub/18993/pg18993.txt')

# %%
response.text
# Out:
# 'ï»¿The Project Gutenberg eBook of History of the World War\r\n    \r\nThis ebook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this ebook or online\r\nat www.gutenberg.org. If you are not located in the United States,\r\nyou will have to check the laws of the country where you are located\r\nbefore using this eBook.\r\n\r\nTitle: History of the World War\r\n        an authentic narrative of the world\'s greatest war\r\n\r\n\r\nAuthor: Richard Joseph Beamish\r\n        Francis Andrew March\r\n\r\nRelease date: August 6, 2006 [eBook #18993]\r\n\r\nLanguage: English\r\n\r\n\r\n\r\n*** START OF THE PROJECT GUTENBERG EBOOK HISTORY OF THE WORLD WAR ***\r\n\r\n\r\n\r\nProduced by Don Kostuch\r\n\r\n\r\n\r\n\r\n\r\n[Transcriber\'s Notes]\r\n\r\nMy father\'s part in WWI attracted me to this book. I recall him talking\r\nbriefly about fighting the Bolsheviki in Archangel. "The machine gun\r\nbullets trimmed the leaves off the trees, as if it were fall." Like most\r\nveterans, he had little else to say.\r\n\r\nThis book mentions his campaign on page 736; "August 3, 1918.--President\r\nWilson announces new policy regarding Russia and agrees to cooperate\r\nwith Great Britain, France and Japan in sending forces to Murmansk,\r\nArchangel and Vladivostok."\r\n\r\nMy father\'s experience seems to be described in the following excerpt\r\nfrom the University of Michigan "The University Record", April 5, 1999.\r\n"Bentley showcases items from World War I \'Polar Bears\'"; by Joanne\r\nNesbit.\r\n\r\n\r\n"During the summer of 1918, the U.S. Army\'s 85th Division, made up\r\nprimarily of men from Michigan and Wisconsin, completed training at Fort\r\nCuster in Battle Creek, Mich., and proceeded to England. The 5,000\r\ntroops of the division\'s 339th Infantry and support units realized that\r\nthey were not being sent to France to join the great battles on the\r\nWestern Front when they were issued Russian weapons and equipment and\r\nlectured on life in the Arctic regions.\r\n\r\n"When they reached their destination in early September, 600 miles north\r\nof Moscow, the men of the 339th joined an international force commanded\r\nby the British that had been sent to northern Russia for purposes that\r\nwere never made clear. The Americans were soon spread in small fighting\r\nunits across hundreds of miles of the Russian forest fighting the\r\nBolsheviks who had taken power in Petrograd and Moscow.\r\n\r\n"The day of the Armistice (Nov. 11) when fighting ceased for other\r\nAmerican armies, the allied soldiers were fighting the Bolsheviks said\r\nto be led by Trotsky himself. After three days, the allies finally were\r\nable to drive off the Bolsheviks. While this fight was a victory for the\r\nAmericans, the battle led to the realization that the war was not over\r\nfor these men. As the weeks and months passed and more battles were\r\nfought, the men began to wonder if they would ever get home.\r\n\r\n"The men of the 339th generally were well equipped with winter clothing\r\nduring the winter of 1918-19 while stationed near the Arctic Circle,\r\nwhere temperatures reached minus 50 degrees Fahrenheit.\r\n\r\n"There was little daylight for months at a time. Knowing that the war was\r\nover for other American soldiers, the morale of the troops declined\r\nthroughout the winter.\r\n\r\n"Families and friends of the men began to clamor for their return.\r\nPoliticians unwilling to support an undeclared war against the Russian\r\ngovernment joined in their demand. A petition to Congress was\r\ncirculated. Several of the British and French units mutinied and refused\r\nto continue fighting. In early April, the American troops learned that\r\nthey would be withdrawn as soon as the harbor at Archangel was cleared\r\nof ice.\r\n\r\n"It was not unti ...

# %%
data = response.text.replace('\r', "").replace("\\'", "'").strip()
data = data.split('\n')

# %%
data[0]
# Out:
# 'ï»¿The Project Gutenberg eBook of History of the World War'

# %%
data[737]
# Out:
# "This is a popular narrative history of the world's greatest war. Written"

# %%
data = data[737:]

# %%
data[0]
# Out:
# "This is a popular narrative history of the world's greatest war. Written"

# %%
len(data)
# Out:
# 26676

# %%
data = " ".join(data)

# %%
data
# Out:
# 'This is a popular narrative history of the world\'s greatest war. Written frankly from the viewpoint of the United States and the Allies, it visualizes the bloodiest and most destructive conflict of all the ages from its remote causes to its glorious conclusion and beneficent results. The world-shaking rise of new democracies is set forth, and the enormous national and individual sacrifices producing that resurrection of human equality are detailed.  Two ideals have been before us in the preparation of this necessary work. These are simplicity and thoroughness. It is of no avail to describe the greatest of human events if the description is so confused that the reader loses interest. Thoroughness is an historical essential beyond price. So it is that official documents prepared in many instances upon the field of battle, and others taken from the files of the governments at war, are the basis of this work. Maps and photographs of unusual clearness and high authenticity illuminate the text. All that has gone into war making, into the regeneration of the world, are herein set forth with historical particularity. The stark horrors of Belgium, the blighting terrors of chemical warfare, the governmental restrictions placed upon hundreds of millions of civilians, the war sacrifices falling upon all the civilized peoples of earth, are in these pages.  It is a book that mankind can well read and treasure.    CHAPTER I  A WAR FOR INTERNATIONAL FREEDOM  "My FELLOW COUNTRYMEN: The armistice was signed this morning. Everything for which America fought has been accomplished. The war thus comes to an end."  Speaking to the Congress and the people of the United States, President Wilson made this declaration on November 11, 1918. A few hours before he made this statement, Germany, the empire of blood and iron, had agreed to an armistice, terms of which were the hardest and most humiliating ever imposed upon a nation of the first class. It was the end of a war for which Germany had prepared for generations, a war bred of a philosophy that Might can take its toll of earth\'s possessions, of human lives and liberties, when and where it will. That philosophy involved the cession to imperial Germany of the best years of young German manhood, the training of German youths to be killers of men. It involved the creation of a military caste, arrogant beyond all precedent, a caste that set its strength and pride against the righteousness of democracy, against the possession of wealth and bodily comforts, a caste that visualized itself as part of a power-mad Kaiser\'s assumption that he and God were to shape the destinies of earth.  When Marshal Foch, the foremost strategist in the world, representing the governments of the Allies and the United States, delivered to the emissaries of Germany terms upon which they might surrender, he brought to an end the bloodiest, the most destructive and the most beneficent war the world has known. It is worthy of note in this connection that the three great wars in which the United States of America engaged have been wars for freedom. The Revolutionary War was for the liberty of the colonies; the Civil War was waged for the freedom of manhood and for the principle of the indissolubility of the Union; the World War, beginning 1914, was fought for the right of small nations to self-government and for the right of every country to the free use of the high seas.  More than four million American men were under arms when the conflict ended. Of these, more than two million were upon the fields of France and Italy. These were thoroughly trained in the military art. They had proved their right to be considered among the most formidable soldiers the world has known. Against the brown rock of that host in khaki, the flower of German savagery and courage had broken at Chateau-Thierry. There the high tide of Prussian militarism, after what had seemed to be an irresistible dash for the destruction of France, spent itself in the b ...

# %%
def clean_text(doc):
  tokens = doc.split()
  table = str.maketrans('','',string.punctuation)
  tokens = [(w.translate(table)) for w in tokens]
  tokens = [word for word in tokens if word.isalpha()]
  tokens = [word.lower() for word in tokens]
  return tokens

# %%
tokens = clean_text(data)

# %%
print(tokens[:50])
# Out:
# ['this', 'is', 'a', 'popular', 'narrative', 'history', 'of', 'the', 'worlds', 'greatest', 'war', 'written', 'frankly', 'from', 'the', 'viewpoint', 'of', 'the', 'united', 'states', 'and', 'the', 'allies', 'it', 'visualizes', 'the', 'bloodiest', 'and', 'most', 'destructive', 'conflict', 'of', 'all', 'the', 'ages', 'from', 'its', 'remote', 'causes', 'to', 'its', 'glorious', 'conclusion', 'and', 'beneficent', 'results', 'the', 'worldshaking', 'rise', 'of']

# %%
len(tokens)
# Out:
# 232751

# %%
len(set(tokens))
# Out:
# 14831

# %%
length = 50 +1
lines = []

for i in range(length, len(tokens)):
  seq = tokens[i-length: i]
  line = ' '.join(seq)
  lines.append(line)
  if i > 200000:
    break

# %%
print(len(lines))
# Out:
# 199951

# %%
lines[0]
# Out:
# 'this is a popular narrative history of the worlds greatest war written frankly from the viewpoint of the united states and the allies it visualizes the bloodiest and most destructive conflict of all the ages from its remote causes to its glorious conclusion and beneficent results the worldshaking rise of new'

# %%
lines[1]
# Out:
# 'is a popular narrative history of the worlds greatest war written frankly from the viewpoint of the united states and the allies it visualizes the bloodiest and most destructive conflict of all the ages from its remote causes to its glorious conclusion and beneficent results the worldshaking rise of new democracies'

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[  21,   33,    6, ..., 2989,    2,   91],
#        [  33,    6, 1135, ...,    2,   91, 3388],
#        [   6, 1135, 4591, ...,   91, 3388,   33],
#        ...,
#        [3881,    2,   19, ...,   12,   19, 1804],
#        [   2,   19,  216, ...,   19, 1804,   55],
#        [  19,  216,    2, ..., 1804,   55,   97]])

# %%
x = sequences[:, :-1]
y = sequences[:, -1]

# %%
x[0]
# Out:
# array([   21,    33,     6,  1135,  4591,   663,     2,     1,  2259,
#          386,    25,  1353,  5701,    18,     1,  7754,     2,     1,
#           94,    83,     3,     1,   105,    15, 13834,     1,  3882,
#            3,   104,  2704,   847,     2,    31,     1,  3386,    18,
#           38,  5700,  4589,     4,    38,  1352,  1421,     3,  5699,
#         1419,     1,  7752,  2989,     2])

# %%
y[0]
# Out:
# 91

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'of': 2,
#  'and': 3,
#  'to': 4,
#  'in': 5,
#  'a': 6,
#  'was': 7,
#  'on': 8,
#  'were': 9,
#  'that': 10,
#  'had': 11,
#  'by': 12,
#  'with': 13,
#  'at': 14,
#  'it': 15,
#  'for': 16,
#  'as': 17,
#  'from': 18,
#  'german': 19,
#  'which': 20,
#  'this': 21,
#  'be': 22,
#  'they': 23,
#  'but': 24,
#  'war': 25,
#  'he': 26,
#  'their': 27,
#  'been': 28,
#  'his': 29,
#  'an': 30,
#  'all': 31,
#  'not': 32,
#  'is': 33,
#  'british': 34,
#  'great': 35,
#  'one': 36,
#  'army': 37,
#  'its': 38,
#  'made': 39,
#  'first': 40,
#  'these': 41,
#  'have': 42,
#  'her': 43,
#  'i': 44,
#  'there': 45,
#  'general': 46,
#  'would': 47,
#  'men': 48,
#  'germany': 49,
#  'american': 50,
#  'into': 51,
#  'against': 52,
#  'government': 53,
#  'when': 54,
#  'who': 55,
#  'two': 56,
#  'germans': 57,
#  'up': 58,
#  'troops': 59,
#  'we': 60,
#  'or': 61,
#  'out': 62,
#  'under': 63,
#  'no': 64,
#  'them': 65,
#  'upon': 66,
#  'time': 67,
#  'french': 68,
#  'more': 69,
#  'only': 70,
#  'after': 71,
#  'line': 72,
#  'enemy': 73,
#  'battle': 74,
#  'other': 75,
#  'are': 76,
#  'so': 77,
#  'could': 78,
#  'then': 79,
#  'about': 80,
#  'russian': 81,
#  'before': 82,
#  'states': 83,
#  'over': 84,
#  'than': 85,
#  'attack': 86,
#  'von': 87,
#  'through': 88,
#  'russia': 89,
#  'some': 90,
#  'new': 91,
#  'our': 92,
#  'day': 93,
#  'united': 94,
#  'three': 95,
#  'france': 96,
#  'will': 97,
#  'she': 98,
#  'during': 99,
#  'guns': 100,
#  'ships': 101,
#  'many': 102,
#  'front': 103,
#  'most': 104,
#  'allies': 105,
#  'has': 106,
#  'now': 107,
#  'every': 108,
#  'allied': 109,
#  'military': 110,
#  'also': 111,
#  'any': 112,
#  'armies': 113,
#  'him': 114,
#  'fire': 115,
#  'if': 116,
#  'did': 117,
#  'fleet': 118,
#  'fighting': 119,
#  'forces': 120,
#  'being': 121,
#  'left': 122,
#  'hundred': 123,
#  'such': 124,
#  'between': 125,
#  'belgium': 126,
#  'world': 127,
#  'people': 128,
#  'submarine': 129,
#  'came': 130,
#  'miles': 131,
#  'soldiers': 132,
#  'back': 133,
#  'country': 134,
#  'sent': 135,
#  'without': 136,
#  'work': 137,
#  'may': 138,
#  'said': 139,
#  'thousand': 140,
#  'took': 141,
#  'officers': 142,
#  'cruisers': 143,
#  'those': 144,
#  'found': 145,
#  'north': 146,
#  'however': 147,
#  'began': 148,
#  'right': 149,
#  'illustration': 150,
#  'second': 151,
#  'where': 152,
#  'sea': 153,
#  'english': 154,
#  'whole': 155,
#  'position': 156,
#  'austria': 157,
#  'advance': 158,
#  'my': 159,
#  'm': 160,
#  'england': 161,
#  'east': 162,
#  'four': 163,
#  'while': 164,
#  'way': 165,
#  'south': 166,
#  'very': 167,
#  'toward': 168,
#  'force': 169,
#  'august': 170,
#  'well': 171,
#  'went': 172,
#  'part': 173,
#  'you': 174,
#  'taken': 175,
#  'what': 176,
#  'ship': 177,
#  'following': 178,
#  'down': 179,
#  'artillery': 180,
#  'turkish': 181,
#  'command': 182,
#  'days': 183,
#  'must': 184,
#  'little': 185,
#  'captured': 186,
#  'corps': 187,
#  'serbia': 188,
#  'action': 189,
#  'long': 190,
#  'until': 191,
#  'peace': 192,
#  'both': 193,
#  'five': 194,
#  'september': 195,
#  'became': 196,
#  'americans': 197,
#  'america': 198,
#  'much': 199,
#  'last': 200,
#  'should': 201,
#  'end': 202,
#  'austrian': 203,
#  'off': 204,
#  'service': 205,
#  'each': 206,
#  'same': 207,
#  'point': 208,
#  'march': 209,
#  'come': 210,
#  'number': 211,
#  'years': 212,
#  'might': 213,
#  'do': 214,
#  'once': 215,
#  'prisoners': 216,
#  'us': 217,
#  'division': 218,
#  'make': 219,
#  'given': 220,
#  'small': 221,
#  'italy': 222,
#  'bulgaria': 223,
#  'even': 224,
#  'still': 225,
#  'power': 226,
#  'mr': 227,
#  'belgian': 228,
#  'shall': 229,
#  'lines': 230,
#  'place': 231,
#  'later': 232,
#  'italian': 233,
#  'high': 234,
#  'another': 235,
#  'along': 236,
#  'president': 237,
#  'held': 238,
#  'heavy': 239,
#  'few': 240,
#  'west': 241,
#  'july': 242,
#  'food': 243,
#  'navy': 244,
#  'man': 245,
#  'october': 246,
#  'received': 247,
#  'used': 248,
#  'almost': 249,
#  'order': 250,
#  'large': 251,
#  'powers': 252,
#  'declared': 253,
#  'lost': 254,
#  'course': 255,
#  'retreat': 256,
#  'king': 257,
#  'own': 258,
#  'submarines': 259,
#  'necessary': 260,
#  'far': 261,
#  'carried': 262,
#  'followed': 263,
#  'women': 264,
#  'city': 265,
#  'cruiser': 266,
#  'trenches': 267,
#  'captain': 268,
#  'take': 269,
#  'naval': 270,
#  'further': 271,
#  'therefore': 272,
#  'sir': 273,
#  'full': 274,
#  'light': 275,
#  'canadian': 276,
#  'november': 277,
#  'themselves': 278,
#  'night': 279,
#  'destroyers': 280,
#  'me': 281,
#  'wounded': 282,
#  'field': 283,
#  'seen': 284,
#  'soon': 285,
#  'vessels': 286,
#  'able': 287,
#  'within': 288,
#  'beginning': 289,
#  'total': 290,
#  'machine': 291,
#  'town': 292,
#  'among': 293,
#  'paris': 294,
#  'possible': 295,
#  'year': 296,
#  'six': 297,
#  'success': 298,
#  'your': 299,
#  'turkey': 300,
#  'put': 301,
#  'again': 302,
#  'turned': 303,
#  'fight': 304,
#  'side': 305,
#  'near': 306,
#  'nations': 307,
#  'never': 308,
#  'torpedo': 309,
#  'imperial': 310,
#  'hindenburg': 311,
#  'immediately': 312,
#  'oclock': 313,
#  'just': 314,
#  'itself': 315,
#  'admiral': 316,
#  'offensive': 317,
#  'squadron': 318,
#  'territory': 319,
#  'brought': 320,
#  'coast': 321,
#  'like': 322,
#  'reached': 323,
#  'done': 324,
#  'destruction': 325,
#  'effort': 326,
#  'because': 327,
#  'can': 328,
#  'morning': 329,
#  'nation': 330,
#  'several': 331,
#  'victory': 332,
#  'tons': 333,
#  'direction': 334,
#  'away': 335,
#  'occupied': 336,
#  'here': 337,
#  'boats': 338,
#  'though': 339,
#  'movement': 340,
#  'policy': 341,
#  'june': 342,
#  'warfare': 343,
#  'armistice': 344,
#  'use': 345,
#  'million': 346,
#  'months': 347,
#  'period': 348,
#  'land': 349,
#  'bulgarian': 350,
#  'neutral': 351,
#  'killed': 352,
#  'losses': 353,
#  'children': 354,
#  'early': 355,
#  'gave': 356,
#  'situation': 357,
#  'commander': 358,
#  'germanys': 359,
#  'attacked': 360,
#  'prince': 361,
#  'continued': 362,
#  'infantry': 363,
#  'life': 364,
#  'good': 365,
#  'control': 366,
#  'old': 367,
#  'minister': 368,
#  'britain': 369,
#  'next': 370,
#  'positions': 371,
#  'turks': 372,
#  'whose': 373,
#  'support': 374,
#  'state': 375,
#  'russians': 376,
#  'strong': 377,
#  'shot': 378,
#  'set': 379,
#  'secretary': 380,
#  'grand': 381,
#  'fact': 382,
#  'himself': 383,
#  'st': 384,
#  'main': 385,
#  'greatest': 386,
#  'having': 387,
#  'officer': 388,
#  'best': 389,
#  'already': 390,
#  'europe': 391,
#  'across': 392,
#  'thousands': 393,
#  'port': 394,
#  'points': 395,
#  'forward': 396,
#  'report': 397,
#  'around': 398,
#  'fell': 399,
#  'speed': 400,
#  'behind': 401,
#  'railway': 402,
#  'effect': 403,
#  'ground': 404,
#  'attacks': 405,
#  'known': 406,
#  'population': 407,
#  'central': 408,
#  'get': 409,
#  'news': 410,
#  'western': 411,
#  'too': 412,
#  'map': 413,
#  'see': 414,
#  'shells': 415,
#  'river': 416,
#  'chapter': 417,
#  'seemed': 418,
#  'death': 419,
#  'foreign': 420,
#  'relief': 421,
#  'plan': 422,
#  'nearly': 423,
#  'moment': 424,
#  'staff': 425,
#  'important': 426,
#  'national': 427,
#  'fought': 428,
#  'committee': 429,
#  'photograph': 430,
#  'supplies': 431,
#  'compelled': 432,
#  'april': 433,
#  'lusitania': 434,
#  'called': 435,
#  'ten': 436,
#  'close': 437,
#  'airplanes': 438,
#  'campaign': 439,
#  'yards': 440,
#  'water': 441,
#  'official': 442,
#  'going': 443,
#  'petrograd': 444,
#  'finally': 445,
#  'third': 446,
#  'half': 447,
#  'salient': 448,
#  'fired': 449,
#  'austrians': 450,
#  'declaration': 451,
#  'hours': 452,
#  'countries': 453,
#  'certain': 454,
#  'destroyed': 455,
#  'commission': 456,
#  'saw': 457,
#  'trench': 458,
#  'result': 459,
#  'shell': 460,
#  'met': 461,
#  'board': 462,
#  'home': 463,
#  'seven': 464,
#  'arrived': 465,
#  'led': 466,
#  'orders': 467,
#  'cross': 468,
#  'entered': 469,
#  'hand': 470,
#  'hour': 471,
#  'purpose': 472,
#  'passed': 473,
#  'divisions': 474,
#  'thus': 475,
#  'empire': 476,
#  'including': 477,
#  'how': 478,
#  'ordered': 479,
#  'political': 480,
#  'told': 481,
#  'moved': 482,
#  'since': 483,
#  'public': 484,
#  'hands': 485,
#  'directed': 486,
#  'complete': 487,
#  'advanced': 488,
#  'minutes': 489,
#  'sunk': 490,
#  'verdun': 491,
#  'surrender': 492,
#  'greece': 493,
#  'red': 494,
#  'canada': 495,
#  'defense': 496,
#  'times': 497,
#  'object': 498,
#  'account': 499,
#  'air': 500,
#  'treaty': 501,
#  'party': 502,
#  'drive': 503,
#  'head': 504,
#  'danger': 505,
#  'capture': 506,
#  'present': 507,
#  'eight': 508,
#  'bank': 509,
#  'conditions': 510,
#  'matter': 511,
#  'munitions': 512,
#  'expedition': 513,
#  'austriahungary': 514,
#  'operation': 515,
#  'lay': 516,
#  'destroyer': 517,
#  'issued': 518,
#  'remained': 519,
#  'opened': 520,
#  'ready': 521,
#  'system': 522,
#  'gun': 523,
#  'cavalry': 524,
#  'marne': 525,
#  'center': 526,
#  'bombs': 527,
#  'terms': 528,
#  'aid': 529,
#  'berlin': 530,
#  'leading': 531,
#  'act': 532,
#  'mine': 533,
#  'operations': 534,
#  'twenty': 535,
#  'range': 536,
#  'carrying': 537,
#  'become': 538,
#  'hit': 539,
#  'making': 540,
#  'placed': 541,
#  'engaged': 542,
#  'seas': 543,
#  'house': 544,
#  'serbian': 545,
#  'throughout': 546,
#  'open': 547,
#  'york': 548,
#  'established': 549,
#  'give': 550,
#  'follows': 551,
#  'according': 552,
#  'gas': 553,
#  'entire': 554,
#  'reported': 555,
#  'nothing': 556,
#  'asked': 557,
#  'eastern': 558,
#  'failed': 559,
#  'village': 560,
#  'serious': 561,
#  'february': 562,
#  'december': 563,
#  'ever': 564,
#  'training': 565,
#  'italians': 566,
#  'fifty': 567,
#  'london': 568,
#  'driven': 569,
#  'p': 570,
#  'neutrality': 571,
#  'flying': 572,
#  'less': 573,
#  'successful': 574,
#  'determined': 575,
#  'railroad': 576,
#  'means': 577,
#  'canal': 578,
#  'airplane': 579,
#  'impossible': 580,
#  'strength': 581,
#  'together': 582,
#  'office': 583,
#  'struck': 584,
#  'announced': 585,
#  'forced': 586,
#  'question': 587,
#  'warsaw': 588,
#  'caused': 589,
#  'distance': 590,
#  'go': 591,
#  'attempt': 592,
#  'brigade': 593,
#  'soldier': 594,
#  'sinking': 595,
#  'revolution': 596,
#  'note': 597,
#  'whom': 598,
#  'keep': 599,
#  'various': 600,
#  'harbor': 601,
#  'charge': 602,
#  'kept': 603,
#  'least': 604,
#  'resistance': 605,
#  'loss': 606,
#  'houses': 607,
#  'above': 608,
#  'others': 609,
#  'japan': 610,
#  'roumania': 611,
#  'suffered': 612,
#  'immediate': 613,
#  'working': 614,
#  'short': 615,
#  'send': 616,
#  'balkan': 617,
#  'firing': 618,
#  'story': 619,
#  'foch': 620,
#  'free': 621,
#  'fields': 622,
#  'africa': 623,
#  'canadians': 624,
#  'dead': 625,
#  'yet': 626,
#  'afternoon': 627,
#  'organization': 628,
#  'kaiser': 629,
#  'members': 630,
#  'leaders': 631,
#  'prussia': 632,
#  'attacking': 633,
#  'fall': 634,
#  'greater': 635,
#  'arms': 636,
#  'cut': 637,
#  'efforts': 638,
#  'returned': 639,
#  'transportation': 640,
#  'leave': 641,
#  'especially': 642,
#  'appeared': 643,
#  'vessel': 644,
#  'always': 645,
#  'case': 646,
#  'flank': 647,
#  'statement': 648,
#  'ended': 649,
#  'china': 650,
#  'won': 651,
#  'chief': 652,
#  'condition': 653,
#  'building': 654,
#  'queen': 655,
#  'practically': 656,
#  'difficult': 657,
#  'name': 658,
#  'commanderinchief': 659,
#  'rear': 660,
#  'battleships': 661,
#  'damage': 662,
#  'history': 663,
#  'liberty': 664,
#  'proved': 665,
#  'message': 666,
#  'sides': 667,
#  'premier': 668,
#  'face': 669,
#  'decided': 670,
#  'famous': 671,
#  'formed': 672,
#  'assistance': 673,
#  'spite': 674,
#  'streets': 675,
#  'move': 676,
#  'succeeded': 677,
#  'southern': 678,
#  'clear': 679,
#  'shipping': 680,
#  'cannot': 681,
#  'millions': 682,
#  'possession': 683,
#  'coming': 684,
#  'duty': 685,
#  'ambassador': 686,
#  'labor': 687,
#  'towns': 688,
#  'destroy': 689,
#  'suddenly': 690,
#  'filled': 691,
#  'apparently': 692,
#  'frontier': 693,
#  'appointed': 694,
#  'group': 695,
#  'reason': 696,
#  'council': 697,
#  'reply': 698,
#  'swept': 699,
#  'enemys': 700,
#  'reports': 701,
#  'de': 702,
#  'completely': 703,
#  'reinforcements': 704,
#  'greek': 705,
#  'crew': 706,
#  'material': 707,
#  'capital': 708,
#  'big': 709,
#  'although': 710,
#  'boat': 711,
#  'single': 712,
#  'taking': 713,
#  'bodies': 714,
#  'painting': 715,
#  'fourth': 716,
#  'twelve': 717,
#  'feeling': 718,
#  'january': 719,
#  'defeated': 720,
#  'moving': 721,
#  'progress': 722,
#  'lieutenant': 723,
#  'feet': 724,
#  'broken': 725,
#  'hope': 726,
#  'modern': 727,
#  'persons': 728,
#  'cause': 729,
#  'true': 730,
#  'return': 731,
#  'nine': 732,
#  'plans': 733,
#  'underwood': 734,
#  'roads': 735,
#  'special': 736,
#  'region': 737,
#  'struggle': 738,
#  'galicia': 739,
#  'got': 740,
#  'knew': 741,
#  'saved': 742,
#  'regiment': 743,
#  'ahead': 744,
#  'gathered': 745,
#  'cracow': 746,
#  'armed': 747,
#  'kerensky': 748,
#  'prepared': 749,
#  'hundreds': 750,
#  'international': 751,
#  'young': 752,
#  'hold': 753,
#  'probably': 754,
#  'except': 755,
#  'showed': 756,
#  'prevent': 757,
#  'money': 758,
#  'places': 759,
#  'turn': 760,
#  'citizens': 761,
#  'am': 762,
#  'obtain': 763,
#  'indeed': 764,
#  'broke': 765,
#  'bolsheviki': 766,
#  'evening': 767,
#  'crossed': 768,
#  'forts': 769,
#  'road': 770,
#  'battleship': 771,
#  'type': 772,
#  'enormous': 773,
#  'civilians': 774,
#  'peoples': 775,
#  'wilson': 776,
#  'blood': 777,
#  'trained': 778,
#  'defeat': 779,
#  'heard': 780,
#  'generals': 781,
#  'believed': 782,
#  'thought': 783,
#  'carry': 784,
#  'ammunition': 785,
#  'former': 786,
#  'poland': 787,
#  'alliance': 788,
#  'business': 789,
#  'vienna': 790,
#  'stand': 791,
#  'week': 792,
#  'increased': 793,
#  'ports': 794,
#  'proceeded': 795,
#  'believe': 796,
#  'y': 797,
#  'motor': 798,
#  'replied': 799,
#  'addition': 800,
#  'developed': 801,
#  'equipment': 802,
#  'commanders': 803,
#  'inhabitants': 804,
#  'easily': 805,
#  'atlantic': 806,
#  'piave': 807,
#  'human': 808,
#  'governments': 809,
#  'india': 810,
#  'fifteen': 811,
#  'thirty': 812,
#  'civilian': 813,
#  'extraordinary': 814,
#  'gained': 815,
#  'particularly': 816,
#  'conference': 817,
#  'felt': 818,
#  'copyright': 819,
#  'battles': 820,
#  'character': 821,
#  'department': 822,
#  'bring': 823,
#  'enthusiasm': 824,
#  'view': 825,
#  'recognized': 826,
#  'know': 827,
#  'considerable': 828,
#  'joined': 829,
#  'terrible': 830,
#  'blow': 831,
#  'nor': 832,
#  'similar': 833,
#  'body': 834,
#  'wire': 835,
#  'effective': 836,
#  'merchant': 837,
#  'built': 838,
#  'austrohungarian': 839,
#  'pass': 840,
#  'bombardment': 841,
#  'steadily': 842,
#  'importance': 843,
#  'duke': 844,
#  'month': 845,
#  'c': 846,
#  'conflict': 847,
#  'evacuated': 848,
#  'beyond': 849,
#  'union': 850,
#  'chateauthierry': 851,
#  'guard': 852,
#  'representatives': 853,
#  'quite': 854,
#  'cost': 855,
#  'huge': 856,
#  'cabinet': 857,
#  'showing': 858,
#  'commerce': 859,
#  'spirit': 860,
#  'previous': 861,
#  'crown': 862,
#  'constantly': 863,
#  'headquarters': 864,
#  'armored': 865,
#  'form': 866,
#  'reserve': 867,
#  'kind': 868,
#  'czar': 869,
#  'communication': 870,
#  'tried': 871,
#  'added': 872,
#  'information': 873,
#  'surprise': 874,
#  'moreover': 875,
#  'squadrons': 876,
#  'tremendous': 877,
#  'northern': 878,
#  'seems': 879,
#  'numbers': 880,
#  'interests': 881,
#  'idea': 882,
#  'per': 883,
#  'smoke': 884,
#  'crews': 885,
#  'congress': 886,
#  'connection': 887,
#  'words': 888,
#  'help': 889,
#  'show': 890,
#  'railroads': 891,
#  'proclamation': 892,
#  'egypt': 893,
#  'transport': 894,
#  'find': 895,
#  'value': 896,
#  'attempted': 897,
#  'station': 898,
#  'affairs': 899,
#  'looked': 900,
#  'regiments': 901,
#  'endeavor': 902,
#  'past': 903,
#  'planned': 904,
#  'ypres': 905,
#  'aug': 906,
#  'seized': 907,
#  'direct': 908,
#  'flag': 909,
#  'operating': 910,
#  'waters': 911,
#  'northwest': 912,
#  'southwest': 913,
#  'wood': 914,
#  'duma': 915,
#  'lives': 916,
#  'delivered': 917,
#  'thoroughly': 918,
#  'merely': 919,
#  'future': 920,
#  'white': 921,
#  'things': 922,
#  'coal': 923,
#  'letter': 924,
#  'warning': 925,
#  'wife': 926,
#  'refused': 927,
#  'attention': 928,
#  'occurred': 929,
#  'authorities': 930,
#  'stated': 931,
#  'influence': 932,
#  'opinion': 933,
#  'lord': 934,
#  'law': 935,
#  'herself': 936,
#  'driving': 937,
#  'commanding': 938,
#  'heavily': 939,
#  'active': 940,
#  'desperate': 941,
#  'occupation': 942,
#  'chinese': 943,
#  'task': 944,
#  'sank': 945,
#  'gulf': 946,
#  'hoover': 947,
#  'sector': 948,
#  'earth': 949,
#  'read': 950,
#  'signed': 951,
#  'marines': 952,
#  'learned': 953,
#  'drove': 954,
#  'call': 955,
#  'european': 956,
#  'closed': 957,
#  'steel': 958,
#  'john': 959,
#  'paid': 960,
#  'associated': 961,
#  'demand': 962,
#  'wireless': 963,
#  'channel': 964,
#  'unable': 965,
#  'washington': 966,
#  'royal': 967,
#  'leaving': 968,
#  'stopped': 969,
#  'company': 970,
#  'accepted': 971,
#  'acting': 972,
#  'mobilization': 973,
#  'remain': 974,
#  'employed': 975,
#  'quickly': 976,
#  'shows': 977,
#  'due': 978,
#  'signal': 979,
#  'supreme': 980,
#  'propaganda': 981,
#  'thrown': 982,
#  'laid': 983,
#  'belgians': 984,
#  'disaster': 985,
#  'cambrai': 986,
#  'utmost': 987,
#  'advancing': 988,
#  'latter': 989,
#  'neuve': 990,
#  'chapelle': 991,
#  'considered': 992,
#  'series': 993,
#  'stood': 994,
#  'construction': 995,
#  'extended': 996,
#  'terrific': 997,
#  'emperor': 998,
#  'entente': 999,
#  'cargo': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 13834

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 13835

# %%
len(set(tokens))
# Out:
# 14831

# %%
y = to_categorical(y, num_classes=vocab_size)

# %%
x.shape[1]
# Out:
# 50

# %%
seq_length = x.shape[1]

# %%
seq_length
# Out:
# 50

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=50, input_length=seq_length))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=vocab_size, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            691750
#
#  lstm (LSTM)                 (None, 50, 100)           60400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 13835)             1397335
#
# =================================================================
# Total params: 2,239,985
# Trainable params: 2,239,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x,y,batch_size=256,epochs=100)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 305s 385ms/step - loss: 6.7748 - accuracy: 0.1046
# Epoch 2/100
# 782/782 [==============================] - 301s 384ms/step - loss: 6.2601 - accuracy: 0.1283
# Epoch 3/100
# 782/782 [==============================] - 301s 385ms/step - loss: 6.0592 - accuracy: 0.1438
# Epoch 4/100
# 782/782 [==============================] - 300s 384ms/step - loss: 5.9004 - accuracy: 0.1562
# Epoch 5/100
# 782/782 [==============================] - 297s 380ms/step - loss: 5.7869 - accuracy: 0.1608
# Epoch 6/100
# 782/782 [==============================] - 298s 381ms/step - loss: 5.6811 - accuracy: 0.1647
# Epoch 7/100
# 782/782 [==============================] - 298s 382ms/step - loss: 5.5855 - accuracy: 0.1678
# Epoch 8/100
# 782/782 [==============================] - 299s 383ms/step - loss: 5.5297 - accuracy: 0.1697
# Epoch 9/100
# 782/782 [==============================] - 300s 384ms/step - loss: 5.4454 - accuracy: 0.1738
# Epoch 10/100
# 782/782 [==============================] - 301s 385ms/step - loss: 5.3545 - accuracy: 0.1776
# Epoch 11/100
# 782/782 [==============================] - 300s 384ms/step - loss: 5.2626 - accuracy: 0.1815
# Epoch 12/100
# 782/782 [==============================] - 302s 386ms/step - loss: 5.1706 - accuracy: 0.1848
# Epoch 13/100
# 782/782 [==============================] - 303s 387ms/step - loss: 5.0799 - accuracy: 0.1881
# Epoch 14/100
# 782/782 [==============================] - 302s 386ms/step - loss: 4.9901 - accuracy: 0.1906
# Epoch 15/100
# 782/782 [==============================] - 304s 388ms/step - loss: 4.9042 - accuracy: 0.1938
# Epoch 16/100
# 782/782 [==============================] - 303s 388ms/step - loss: 4.8233 - accuracy: 0.1959
# Epoch 17/100
# 782/782 [==============================] - 302s 387ms/step - loss: 4.7446 - accuracy: 0.1986
# Epoch 18/100
# 782/782 [==============================] - 304s 389ms/step - loss: 4.6691 - accuracy: 0.2018
# Epoch 19/100
# 782/782 [==============================] - 304s 388ms/step - loss: 4.5992 - accuracy: 0.2047
# Epoch 20/100
# 782/782 [==============================] - 302s 386ms/step - loss: 4.5306 - accuracy: 0.2084
# Epoch 21/100
# 782/782 [==============================] - 304s 388ms/step - loss: 4.4658 - accuracy: 0.2126
# Epoch 22/100
# 782/782 [==============================] - 306s 392ms/step - loss: 4.4058 - accuracy: 0.2162
# Epoch 23/100
# 782/782 [==============================] - 305s 390ms/step - loss: 4.3473 - accuracy: 0.2208
# Epoch 24/100
# 782/782 [==============================] - 307s 393ms/step - loss: 4.2913 - accuracy: 0.2246
# Epoch 25/100
# 782/782 [==============================] - 309s 395ms/step - loss: 4.2393 - accuracy: 0.2288
# Epoch 26/100
# 782/782 [==============================] - 307s 393ms/step - loss: 4.1897 - accuracy: 0.2328
# Epoch 27/100
# 782/782 [==============================] - 309s 395ms/step - loss: 4.1417 - accuracy: 0.2375
# Epoch 28/100
# 782/782 [==============================] - 308s 394ms/step - loss: 4.0935 - accuracy: 0.2412
# Epoch 29/100
# 782/782 [==============================] - 310s 397ms/step - loss: 4.0469 - accuracy: 0.2467
# Epoch 30/100
# 782/782 [==============================] - 311s 398ms/step - loss: 4.0034 - accuracy: 0.2502
# Epoch 31/100
# 782/782 [==============================] - 312s 399ms/step - loss: 3.9610 - accuracy: 0.2552
# Epoch 32/100
# 782/782 [==============================] - 312s 400ms/step - loss: 3.9205 - accuracy: 0.2588
# Epoch 33/100
# 782/782 [==============================] - 312s 399ms/step - loss: 3.8785 - accuracy: 0.2636
# Epoch 34/100
# 782/782 [==============================] - 313s 400ms/step - loss: 3.8417 - accuracy: 0.2674
# Epoch 35/100
# 782/782 [==============================] - 313s 400ms/step - loss: 3.8020 - accuracy: 0.2724
# Epoch 36/100
# 782/782 [==============================] - 314s 401ms/step - loss: 3.7649 - accuracy: 0.2767
# Epoch 37/100
# 782/782 [==============================] - 313s 401ms/step - loss: 3.7288 - accuracy: 0.2821
# Epoch 38/100
# 782/782 [==============================] - 313s 401ms/step - loss: 3.6929 - accuracy: 0.2853
# Epoch 39/100
# 782/782 [==============================] - 315s 403ms/step - loss: 3.6617 - accuracy: 0.2891
# Epoch 40/100
# 782/782 [==============================] - 315s 403ms/step - loss: 3.6263 - accuracy: 0.2936
# Epoch 41/100
# 782/782 [==============================] - 317s 406ms/step - loss: 3.5896 - accuracy: 0.2980
# Epoch 42/100
# 782/782 [==============================] - 316s 404ms/step - loss: 3.5576 - accuracy: 0.3018
# Epoch 43/100
# 782/782 [==============================] - 317s 406ms/step - loss: 3.5238 - accuracy: 0.3061
# Epoch 44/100
# 782/782 [==============================] - 319s 408ms/step - loss: 3.4951 - accuracy: 0.3092
# Epoch 45/100
# 782/782 [==============================] - 322s 412ms/step - loss: 3.4635 - accuracy: 0.3133
# Epoch 46/100
# 782/782 [==============================] - 321s 411ms/step - loss: 3.4339 - accuracy: 0.3174
# Epoch 47/100
# 782/782 [==============================] - 323s 413ms/step - loss: 3.4045 - accuracy: 0.3207
# Epoch 48/100
# 782/782 [==============================] - 324s 414ms/step - loss: 3.3724 - accuracy: 0.3261
# Epoch 49/100
# 782/782 [==============================] - 323s 414ms/step - loss: 3.3447 - accuracy: 0.3303
# Epoch 50/100
# 782/782 [==============================] - 323s 413ms/step - loss: 3.3180 - accuracy: 0.3333
# Epoch 51/100
# 782/782 [==============================] - 323s 413ms/step - loss: 3.2875 - accuracy: 0.3370
# Epoch 52/100
# 782/782 [==============================] - 324s 414ms/step - loss: 3.2591 - accuracy: 0.3411
# Epoch 53/100
# 782/782 [==============================] - 325s 415ms/step - loss: 3.2340 - accuracy: 0.3442
# Epoch 54/100
# 782/782 [==============================] - 326s 417ms/step - loss: 3.2072 - accuracy: 0.3489
# Epoch 55/100
# 782/782 [==============================] - 326s 416ms/step - loss: 3.1801 - accuracy: 0.3523
# Epoch 56/100
# 782/782 [==============================] - 325s 415ms/step - loss: 3.1546 - accuracy: 0.3562
# Epoch 57/100
# 782/782 [==============================] - 325s 415ms/step - loss: 3.1291 - accuracy: 0.3597
# Epoch 58/100
# 782/782 [==============================] - 327s 418ms/step - loss: 3.1049 - accuracy: 0.3632
# Epoch 59/100
# 782/782 [==============================] - 325s 416ms/step - loss: 3.0810 - accuracy: 0.3668
# Epoch 60/100
# 782/782 [==============================] - 324s 414ms/step - loss: 3.0531 - accuracy: 0.3717
# Epoch 61/100
# 782/782 [==============================] - 326s 417ms/step - loss: 3.0304 - accuracy: 0.3738
# Epoch 62/100
# 782/782 [==============================] - 322s 412ms/step - loss: 3.0101 - accuracy: 0.3767
# Epoch 63/100
# 782/782 [==============================] - 323s 414ms/step - loss: 2.9856 - accuracy: 0.3810
# Epoch 64/100
# 782/782 [==============================] - 321s 411ms/step - loss: 2.9608 - accuracy: 0.3847
# Epoch 65/100
# 782/782 [==============================] - 323s 414ms/step - loss: 2.9382 - accuracy: 0.3878
# Epoch 66/100
# 782/782 [==============================] - 321s 410ms/step - loss: 2.9153 - accuracy: 0.3918
# Epoch 67/100
# 782/782 [==============================] - 323s 413ms/step - loss: 2.8957 - accuracy: 0.3944
# Epoch 68/100
# 782/782 [==============================] - 325s 416ms/step - loss: 2.8690 - accuracy: 0.3983
# Epoch 69/100
# 782/782 [==============================] - 323s 414ms/step - loss: 2.8508 - accuracy: 0.4008
# Epoch 70/100
# 782/782 [==============================] - 327s 418ms/step - loss: 2.8290 - accuracy: 0.4039
# Epoch 71/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.8089 - accuracy: 0.4075
# Epoch 72/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.7877 - accuracy: 0.4106
# Epoch 73/100
# 782/782 [==============================] - 325s 416ms/step - loss: 2.7706 - accuracy: 0.4138
# Epoch 74/100
# 782/782 [==============================] - 326s 416ms/step - loss: 2.7470 - accuracy: 0.4175
# Epoch 75/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.7296 - accuracy: 0.4197
# Epoch 76/100
# 782/782 [==============================] - 324s 414ms/step - loss: 2.7112 - accuracy: 0.4228
# Epoch 77/100
# 782/782 [==============================] - 325s 416ms/step - loss: 2.6891 - accuracy: 0.4264
# Epoch 78/100
# 782/782 [==============================] - 323s 413ms/step - loss: 2.6697 - accuracy: 0.4290
# Epoch 79/100
# 782/782 [==============================] - 325s 416ms/step - loss: 2.6548 - accuracy: 0.4313
# Epoch 80/100
# 782/782 [==============================] - 325s 416ms/step - loss: 2.6340 - accuracy: 0.4352
# Epoch 81/100
# 782/782 [==============================] - 325s 416ms/step - loss: 2.6154 - accuracy: 0.4388
# Epoch 82/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.5992 - accuracy: 0.4407
# Epoch 83/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.5758 - accuracy: 0.4456
# Epoch 84/100
# 782/782 [==============================] - 326s 416ms/step - loss: 2.5641 - accuracy: 0.4469
# Epoch 85/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.5479 - accuracy: 0.4493
# Epoch 86/100
# 782/782 [==============================] - 327s 419ms/step - loss: 2.5300 - accuracy: 0.4519
# Epoch 87/100
# 782/782 [==============================] - 326s 417ms/step - loss: 2.5106 - accuracy: 0.4558
# Epoch 88/100
# 782/782 [==============================] - 331s 423ms/step - loss: 2.4952 - accuracy: 0.4587
# Epoch 89/100
# 782/782 [==============================] - 330s 422ms/step - loss: 2.4777 - accuracy: 0.4606
# Epoch 90/100
# 782/782 [==============================] - 330s 422ms/step - loss: 2.4609 - accuracy: 0.4634
# Epoch 91/100
# 782/782 [==============================] - 331s 424ms/step - loss: 2.4469 - accuracy: 0.4670
# Epoch 92/100
# 782/782 [==============================] - 333s 425ms/step - loss: 2.4329 - accuracy: 0.4685
# Epoch 93/100
# 782/782 [==============================] - 331s 424ms/step - loss: 2.4138 - accuracy: 0.4729
# Epoch 94/100
# 782/782 [==============================] - 333s 426ms/step - loss: 2.4031 - accuracy: 0.4732
# Epoch 95/100
# 782/782 [==============================] - 335s 428ms/step - loss: 2.3811 - accuracy: 0.4769
# Epoch 96/100
# 782/782 [==============================] - 333s 426ms/step - loss: 2.3731 - accuracy: 0.4779
# Epoch 97/100
# 782/782 [==============================] - 331s 424ms/step - loss: 2.3609 - accuracy: 0.4809
# Epoch 98/100
# 782/782 [==============================] - 329s 421ms/step - loss: 2.3441 - accuracy: 0.4830
# Epoch 99/100
# 782/782 [==============================] - 334s 427ms/step - loss: 2.3257 - accuracy: 0.4860
# Epoch 100/100
# 782/782 [==============================] - 334s 427ms/step - loss: 2.3108 - accuracy: 0.4887

# %%
lines[10299]
# Out:
# 'the language in which the ultimatum was couched was humiliating to serbia the answer was duly delivered within the stipulated time the demands of the austrian note in brief were as follows the serbian government to give formal assurance of its condemnation of serb propaganda against austria the next issue of'

# %%
seed_text = lines[10299]

# %%
def generate_text_seq(model, tokenizer, text_seq_length, seed_text, n_words):
    text = []
    
    for _ in range(n_words):
        encoded = tokenizer.texts_to_sequences([seed_text])[0]
        encoded = pad_sequences([encoded], maxlen = text_seq_length, truncating='pre')
        
        y_predict = model.predict(encoded)[0]
        
        predicted_word_idx = np.argmax(y_predict)
        
        predicted_word = ''
        for word, index in tokenizer.word_index.items():
            if index == predicted_word_idx:
                predicted_word = word
                break
        seed_text = seed_text + ' ' + predicted_word
        text.append(predicted_word)
    
    return ' '.join(text)

# %%
generate_text_seq(model, tokenizer, seq_length, seed_text, 10)
# Out:
# 1/1 [==============================] - 1s 719ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 'the war the majority of the turkish conscription had grown'

# %%
seed_text = 'The german initiated the war because they are'

# %%
generate_text_seq(model, tokenizer, seq_length, seed_text, 10)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 'talking to drive and in the neighborhood of plava the'
